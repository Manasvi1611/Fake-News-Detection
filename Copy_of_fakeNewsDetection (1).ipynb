# %%
#import requires libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import nltk
import re
from wordcloud import WordCloud

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Conv1D,MaxPool1D
from sklearn.metrics import classification_report,accuracy_score

# %% [markdown]
# Explore fake news dataset

# %%
#explore fake dataset
fake = pd.read_csv("/content/Fake_data.csv")
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
#types of subjects in fake data
fake["subject"].value_counts()
# Out:
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: subject, dtype: int64

# %%
plt.figure(figsize =(10,6))
sns.countplot(x = "subject" ,data = fake)

# %% [markdown]
# WORLDCLOUD

# %%
 #convert text column into list
 ls = fake["text"].tolist()
 #join the list into a string
 text = " ".join(ls)
 wordcloud = WordCloud(width = 1920,height = 1080).generate(text)
 fig = plt.figure(figsize = (10,20))
 plt.imshow(wordcloud)
 plt.axis("off")
 plt.tight_layout(pad = 0)
 plt.show()

# %% [markdown]
# Explore real news dataset

# %%
true = pd.read_csv("/content/True_data.csv")
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
#columns in true data set
true.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
#types of subjects in true data
true["subject"].value_counts()
# Out:
# politicsNews    11272
# worldnews       10145
# Name: subject, dtype: int64

# %%
plt.figure(figsize =(10,6))
sns.countplot(x = "subject" ,data = true)

# %%
#creating wordcloud for true news
#convert text column into list
ls = true["text"].tolist()
#join the list into a string
text = " ".join(ls)
wordcloud = WordCloud(width = 1920,height = 1080).generate(text)
fig = plt.figure(figsize = (10,20))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# Difference in Text
# Real news seems to have source of publications  which is not present in fake dataset
# Looking at the data:
#
#
# *  most of the text contains reuters information such as "WASHINGTON (reuters)"
# *   Some text are tweets from twitter.
# *   Few texts do not contain any publication information

# %% [markdown]
# Cleaning Of Data
# Removing reuters or twitter tweet information from the text .
#
#
# *   text can b.e splitted only once at "-" which is always present after mentioning source of publication, this gives us publication part and the text part
# *  If we do not get the text part , this means publication details was not given for that record.
#
#
#
#
# *  The Twitter tweets always have some source, a long text of max 259 characters

# %%
true.sample(5)
# Out:
#                                                    title  \
# 3301   Former FBI chief's ire over Trump laid bare in...
# 1828   Moderate Republican U.S. congressman Dent will...
# 11214  House committee seeks testimony from 'Pharma B...
# 5512   Japan's love of tiny cars sore spot as Trump, ...
# 7142   Obama says not worried about being last Democr...
#
#                                                     text       subject  \
# 3301   WASHINGTON (Reuters) - Throughout the drama of...  politicsNews
# 1828   WASHINGTON (Reuters) - U.S. Representative Cha...  politicsNews
# 11214  WASHINGTON (Reuters) - A U.S. congressional pa...  politicsNews
# 5512    TOKYO/DETROIT (Reuters) - When Japanese Prime...  politicsNews
# 7142   LIMA (Reuters) - U.S. President Barack Obama o...  politicsNews
#
#                      date
# 3301        June 8, 2017
# 1828   September 8, 2017
# 11214   January 15, 2016
# 5512   February 10, 2017
# 7142   November 20, 2016

# %%
# creating a list of indexes that do not have publications
unknown_publishers = []
for index, row in enumerate(true.text.values):
  try:
    record = row.split("-", maxsplit = 1)
    record[1]
    assert(len(record[0])<120)
  except:
    unknown_publishers.append(index)

# %%
len(unknown_publishers)
# Out:
# 222

# %%
#list the text of unknown publishers
true.iloc[unknown_publishers].text
# Out:
# 7        The following statements were posted to the ve...
# 8        The following statements were posted to the ve...
# 12       The following statements were posted to the ve...
# 13       The following statements were posted to the ve...
# 14        (In Dec. 25 story, in second paragraph, corre...
#                                ...
# 20135     (Story corrects to million from billion in pa...
# 20500     (This Sept 8 story corrects headline, clarifi...
# 20667     (Story refiles to add dropped word  not , in ...
# 21246     (Story corrects third paragraph to show Mosul...
# 21339     (Story corrects to fix spelling in paragraph ...
# Name: text, Length: 222, dtype: object

# %%
#list of known publishers
publishers = []
tmp_text =[]

for index , row in enumerate (true.text.values):
  if index in unknown_publishers:
    tmp_text.append(row)
    publishers.append("unknown")
    
  else:
      record = row.split("-",maxsplit = 1)
      publishers.append(record[0].strip())
      tmp_text.append(record[1].strip())

# %%
true["publishers"] = publishers
true["text"] = tmp_text

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  The head of a conservative Republican faction ...  politicsNews
# 1  Transgender people will be allowed for the fir...  politicsNews
# 2  The special counsel investigation of links bet...  politicsNews
# 3  Trump campaign adviser George Papadopoulos tol...  politicsNews
# 4  President Donald Trump called on the U.S. Post...  politicsNews
#
#                  date                    publishers
# 0  December 31, 2017           WASHINGTON (Reuters)
# 1  December 29, 2017           WASHINGTON (Reuters)
# 2  December 31, 2017           WASHINGTON (Reuters)
# 3  December 30, 2017           WASHINGTON (Reuters)
# 4  December 29, 2017   SEATTLE/WASHINGTON (Reuters)

# %%
true.shape
# Out:
# (21417, 5)

# %%
#to check whether fake news dataset has any empty text field 
empty_fake_index = [index for index,text in enumerate(fake.text.tolist()) if str(text).strip()== ""]
fake.iloc[empty_fake_index]
# Out:
#                                                    title text    subject  \
# 10923  TAKE OUR POLL: Who Do You Think President Trum...        politics
# 11041  Joe Scarborough BERATES Mika Brzezinski Over “...        politics
# 11190  WATCH TUCKER CARLSON Scorch Sanctuary City May...        politics
# 11225  MAYOR OF SANCTUARY CITY: Trump Trying To Make ...        politics
# 11236  SHOCKER: Public School Turns Computer Lab Into...        politics
# ...                                                  ...  ...        ...
# 21816  BALTIMORE BURNS: MARYLAND GOVERNOR BRINGS IN N...       left-news
# 21826  FULL VIDEO: THE BLOCKBUSTER INVESTIGATION INTO...       left-news
# 21827  (VIDEO) HILLARY CLINTON: RELIGIOUS BELIEFS MUS...       left-news
# 21857  (VIDEO)ICE PROTECTING OBAMA: WON’T RELEASE NAM...       left-news
# 21873  (VIDEO) HYSTERICAL SNL TAKE ON HILLARY’S ANNOU...       left-news
#
#                date
# 10923  May 10, 2017
# 11041  Apr 26, 2017
# 11190   Apr 6, 2017
# 11225   Apr 2, 2017
# 11236   Apr 1, 2017
# ...             ...
# 21816  Apr 27, 2015
# 21826  Apr 25, 2015
# 21827  Apr 25, 2015
# 21857  Apr 14, 2015
# 21873  Apr 12, 2015
#
# [630 rows x 4 columns]

# %%
#the text of these rows seems to be present in the title 
#removing the rows with empty text field
true["text"] = true["title"] + " " + true["text"]
fake["text"] = fake["title"] + " " + fake["text"]

# %%
#preprocessing 
#converting all the text to lower

true['text'] = true['text'].apply(lambda x:str(x).lower())
fake['text'] = fake['text'].apply(lambda x:str(x).lower())

# %% [markdown]
# PREPROCESSING TEXT

# %%
#assigning labels to the news
true['class'] = 1
fake['class'] = 0

# %%
true.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'publishers', 'class'], dtype='object')

# %%
#getting the required columns
Ttrue = true [['text' , 'class']]
Ffake = fake [['text' , 'class']]
#append the true and the fake and true data together
data = Ttrue.append(Ffake,ignore_index = True)

# %%
# !pip install spacy==2.2.3
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoup4==4.9.1
# !pip install textblob==0.15.3
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting spacy==2.2.3
#   Downloading spacy-2.2.3-cp37-cp37m-manylinux1_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 4.5 MB/s
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (0.4.1)
# Collecting thinc<7.4.0,>=7.3.0
#   Downloading thinc-7.3.1-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 38.3 MB/s
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (1.0.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (0.9.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (1.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==2.2.3) (2.23.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.2.3) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.2.3) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.2.3) (3.8.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2022.5.18.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.4.0,>=7.3.0->spacy==2.2.3) (4.64.0)
# Installing collected packages: thinc, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed spacy-2.2.3 thinc-7.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 5.2 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.3.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2022.5.18.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.7/dist-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.64.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting beautifulsoup4==4.9.1
#   Downloading beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 5.2 MB/s
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4==4.9.1) (2.3.2.post1)
# Installing collected packages: beautifulsoup4
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed beautifulsoup4-4.9.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: textblob==0.15.3 in /usr/local/lib/python3.7/dist-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.7/dist-packages (from textblob==0.15.3) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk>=3.1->textblob==0.15.3) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to /tmp/pip-req-build-fyydgs6w
#   Running command git clone -q https://github.com/laxmimerit/preprocess_kgptalkie.git /tmp/pip-req-build-fyydgs6w
# Building wheels for collected packages: preprocess-kgptalkie
#   Building wheel for preprocess-kgptalkie (setup.py) ... done
#   Created wheel for preprocess-kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=11756 sha256=59178903185927fdd95fe2d4b7d946cc2050fdc62878c6f23e9b603414fd7491
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v8xk0hpx/wheels/0d/b3/29/bfe3deffda68980088d17b81331be6667e837ffb4a071bae82
# Successfully built preprocess-kgptalkie
# Installing collected packages: preprocess-kgptalkie
# Successfully installed preprocess-kgptalkie-0.1.3

# %%
#removing special characters 
import preprocess_kgptalkie as ps
data["text"] = data["text"].apply(lambda x : ps.remove_special_chars(x))

# %% [markdown]
# #converting text data into numerical data

# %% [markdown]
# Word2vec is one of the most popular technique to learn word embeddings using shallow neural network. It was developed by Thomas Mikolov in 2013 at Google.
# Word embedding is one of the most popular representation of the document vocabulary.It is capable of capturing the context of the word in a document , sematics and syntactic similarity ,relation with other words etc. ![word2vec.png](data:image/png;base64,...)

# %%
# word to vec using gensim  library
import gensim
y = data["class"].values
#x is list of words
x = [d.split() for d in data["text"].tolist()]

# %%
# word will be converted into sequence of 100 vectors
DIM = 100
w2v_model = gensim.models.Word2Vec(sentences = x,size = DIM ,window = 10, min_count = 1)

# %%
len(w2v_model.wv.vocab)
# Out:
# 231911

# %%
w2v_model.wv["love"]
# Out:
# array([ 1.2013565e-01, -5.6633401e+00, -1.7205703e+00, -2.2613537e+00,
#        -1.7574425e+00, -1.1907017e+00, -2.9603314e+00, -2.9502466e+00,
#        -5.9338445e-03, -6.2388766e-01,  7.2647445e-02, -3.0730557e-01,
#         1.0497167e+00,  1.7028066e+00,  9.2080766e-01, -1.3230104e+00,
#        -1.3527319e+00,  5.1679009e-01, -3.9076610e+00, -1.6151338e+00,
#         5.9745927e+00,  2.3901677e+00,  9.4603229e-01, -2.4719667e-02,
#        -1.5349996e+00,  1.0509170e-01,  1.1369998e+00, -3.1390619e-01,
#         5.3761464e-01, -8.5476118e-01, -1.8041219e-01,  1.9248329e+00,
#         1.1323432e+00, -3.3786154e-01,  1.3780036e+00, -3.4079230e-01,
#         2.9695737e-01, -1.1189826e+00, -1.6292790e-01,  1.8354844e-01,
#        -7.9905939e+00, -5.9293962e-01, -1.6561116e+00, -2.2430110e+00,
#        -1.8228278e-01,  1.2312325e+00, -1.1956246e+00, -1.6377302e+00,
#        -2.2719910e+00, -2.6411080e+00, -2.7145877e+00, -1.1955173e+00,
#        -2.6841050e-01,  1.1252708e+00,  3.4741735e+00,  8.3677113e-01,
#         4.1381936e+00,  4.1649752e+00,  2.0603330e+00, -1.4148881e+00,
#        -3.2231870e-01,  3.9128239e+00,  1.2981997e+00,  1.1007769e+00,
#         2.3374560e+00,  1.3240238e+00,  2.0035989e+00,  1.9537610e+00,
#        -1.3156407e+00, -2.1354871e+00,  5.0499183e-01, -8.5143739e-01,
#         5.7474488e-01,  1.4701848e+00, -2.4309187e+00,  8.2036841e-01,
#        -2.8157666e-01,  4.0025535e+00, -4.6934095e-01,  1.4898502e+00,
#        -2.6167941e+00,  2.3085673e+00, -1.0946405e+00, -1.1268820e+00,
#         1.1394301e-01,  4.4136459e-01,  1.8533053e+00, -3.3242919e+00,
#        -1.0166962e+00, -2.9392022e-01, -4.5921788e+00, -1.7507882e+00,
#        -2.7463322e+00, -1.1533693e+00,  1.4961511e+00, -3.3871419e+00,
#         2.1474388e+00, -7.5975615e-01, -1.1989495e+00,  4.3086038e+00],
#       dtype=float32)

# %%
#exploring the vectors
w2v_model.wv["india"]
w2v_model.wv.most_similar("india")
# Out:
# [('pakistan', 0.7431882619857788),
#  ('malaysia', 0.7045928835868835),
#  ('indias', 0.6483880281448364),
#  ('china', 0.6466995477676392),
#  ('norway', 0.635319709777832),
#  ('indian', 0.632917046546936),
#  ('beijings', 0.6272697448730469),
#  ('australia', 0.5987348556518555),
#  ('maritime', 0.5867645144462585),
#  ('senegal', 0.5858911871910095)]

# %%
w2v_model.wv.most_similar("china")
# Out:
# [('beijing', 0.8490604758262634),
#  ('taiwan', 0.8045223355293274),
#  ('chinas', 0.7632561922073364),
#  ('chinese', 0.701541543006897),
#  ('pyongyang', 0.6801574230194092),
#  ('waterway', 0.6526803970336914),
#  ('beijings', 0.6491953134536743),
#  ('india', 0.6466995477676392),
#  ('japan', 0.6399459838867188),
#  ('xi', 0.6283771991729736)]

# %%
w2v_model.wv.most_similar("modi")
# Out:
# [('narendra', 0.7596169114112854),
#  ('modis', 0.6608402729034424),
#  ('india', 0.5744475722312927),
#  ('najib', 0.5427131652832031),
#  ('abe', 0.5376186370849609),
#  ('premier', 0.5358973741531372),
#  ('usindia', 0.5321942567825317),
#  ('movetrump', 0.5306423306465149),
#  ('indias', 0.5250353217124939),
#  ('tokyo', 0.5200173854827881)]

# %%
w2v_model.wv.most_similar("trump")
# Out:
# [('trumps', 0.7310428619384766),
#  ('trumpthe', 0.5766953229904175),
#  ('him', 0.5370162129402161),
#  ('trumptrump', 0.5348323583602905),
#  ('smilefeatured', 0.5293625593185425),
#  ('he', 0.5291314125061035),
#  ('rumsfeld', 0.52315753698349),
#  ('presidentelect', 0.5201758146286011),
#  ('cruz', 0.5166608095169067),
#  ('trumpfeatured', 0.5157501697540283)]

# %% [markdown]
# To train the dataset we will will feed the vectors as initial weight to our training model

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x)

# %%
#vectors to sequence for the dataset
x = tokenizer.texts_to_sequences(x)
#x

# %%
#tokenizer.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'of': 3,
#  'a': 4,
#  'and': 5,
#  'in': 6,
#  'that': 7,
#  'on': 8,
#  'for': 9,
#  's': 10,
#  'is': 11,
#  'he': 12,
#  'said': 13,
#  'trump': 14,
#  'it': 15,
#  'with': 16,
#  'was': 17,
#  'as': 18,
#  'his': 19,
#  'by': 20,
#  'has': 21,
#  'be': 22,
#  'have': 23,
#  'not': 24,
#  'from': 25,
#  'this': 26,
#  'at': 27,
#  'are': 28,
#  'who': 29,
#  'us': 30,
#  'an': 31,
#  'they': 32,
#  'i': 33,
#  'but': 34,
#  'we': 35,
#  'would': 36,
#  'president': 37,
#  'about': 38,
#  'will': 39,
#  'their': 40,
#  'had': 41,
#  'you': 42,
#  't': 43,
#  'been': 44,
#  'were': 45,
#  'people': 46,
#  'more': 47,
#  'or': 48,
#  'after': 49,
#  'which': 50,
#  'she': 51,
#  'her': 52,
#  'one': 53,
#  'if': 54,
#  'its': 55,
#  'out': 56,
#  'all': 57,
#  'what': 58,
#  'state': 59,
#  'when': 60,
#  'new': 61,
#  'also': 62,
#  'up': 63,
#  'there': 64,
#  'over': 65,
#  'no': 66,
#  'house': 67,
#  'donald': 68,
#  'our': 69,
#  'states': 70,
#  'clinton': 71,
#  'obama': 72,
#  'government': 73,
#  'can': 74,
#  'just': 75,
#  'him': 76,
#  'so': 77,
#  'than': 78,
#  'republican': 79,
#  'other': 80,
#  'some': 81,
#  'could': 82,
#  'white': 83,
#  'into': 84,
#  'told': 85,
#  'united': 86,
#  'against': 87,
#  'like': 88,
#  'do': 89,
#  'because': 90,
#  'campaign': 91,
#  'them': 92,
#  'news': 93,
#  'any': 94,
#  'last': 95,
#  'election': 96,
#  'two': 97,
#  'time': 98,
#  'now': 99,
#  'how': 100,
#  'party': 101,
#  'first': 102,
#  'only': 103,
#  'former': 104,
#  'hillary': 105,
#  'should': 106,
#  'even': 107,
#  'being': 108,
#  'year': 109,
#  'while': 110,
#  'country': 111,
#  'video': 112,
#  'did': 113,
#  'before': 114,
#  'years': 115,
#  'during': 116,
#  'many': 117,
#  'media': 118,
#  'security': 119,
#  'may': 120,
#  'most': 121,
#  'say': 122,
#  'political': 123,
#  'national': 124,
#  'police': 125,
#  'get': 126,
#  'law': 127,
#  'made': 128,
#  'court': 129,
#  'make': 130,
#  'those': 131,
#  'american': 132,
#  'republicans': 133,
#  'since': 134,
#  'going': 135,
#  'where': 136,
#  'percent': 137,
#  'trumps': 138,
#  'bill': 139,
#  'presidential': 140,
#  'under': 141,
#  'very': 142,
#  'back': 143,
#  'these': 144,
#  'says': 145,
#  'russia': 146,
#  'north': 147,
#  'senate': 148,
#  'support': 149,
#  'democratic': 150,
#  'administration': 151,
#  'vote': 152,
#  'america': 153,
#  'down': 154,
#  'week': 155,
#  'between': 156,
#  'including': 157,
#  'group': 158,
#  'then': 159,
#  'know': 160,
#  'officials': 161,
#  'think': 162,
#  'according': 163,
#  'way': 164,
#  'take': 165,
#  'public': 166,
#  'office': 167,
#  'federal': 168,
#  'military': 169,
#  'such': 170,
#  'my': 171,
#  'foreign': 172,
#  'called': 173,
#  're': 174,
#  'via': 175,
#  'right': 176,
#  'million': 177,
#  'world': 178,
#  'statement': 179,
#  'department': 180,
#  'washington': 181,
#  'want': 182,
#  'saying': 183,
#  'tax': 184,
#  'don': 185,
#  'well': 186,
#  'see': 187,
#  'here': 188,
#  'congress': 189,
#  'still': 190,
#  'russian': 191,
#  'tuesday': 192,
#  'both': 193,
#  'your': 194,
#  'much': 195,
#  'democrats': 196,
#  'image': 197,
#  'another': 198,
#  'minister': 199,
#  'day': 200,
#  'women': 201,
#  'part': 202,
#  'wednesday': 203,
#  'go': 204,
#  'work': 205,
#  'through': 206,
#  'china': 207,
#  'policy': 208,
#  'friday': 209,
#  'thursday': 210,
#  'asked': 211,
#  'war': 212,
#  'own': 213,
#  'black': 214,
#  'deal': 215,
#  'rights': 216,
#  'off': 217,
#  'city': 218,
#  'official': 219,
#  'secretary': 220,
#  'why': 221,
#  'monday': 222,
#  '2016': 223,
#  'americans': 224,
#  'committee': 225,
#  'next': 226,
#  'me': 227,
#  'help': 228,
#  'general': 229,
#  'need': 230,
#  'korea': 231,
#  'three': 232,
#  'whether': 233,
#  'leader': 234,
#  'case': 235,
#  'senator': 236,
#  'show': 237,
#  'never': 238,
#  'man': 239,
#  'around': 240,
#  'york': 241,
#  'does': 242,
#  'order': 243,
#  'fbi': 244,
#  'members': 245,
#  'use': 246,
#  'candidate': 247,
#  'report': 248,
#  'same': 249,
#  'meeting': 250,
#  'took': 251,
#  'good': 252,
#  'come': 253,
#  'every': 254,
#  'iran': 255,
#  'end': 256,
#  'left': 257,
#  'without': 258,
#  'reuters': 259,
#  'power': 260,
#  'used': 261,
#  'really': 262,
#  'top': 263,
#  'twitter': 264,
#  'attack': 265,
#  'put': 266,
#  'investigation': 267,
#  'intelligence': 268,
#  'times': 269,
#  'countries': 270,
#  'justice': 271,
#  'money': 272,
#  'nuclear': 273,
#  'syria': 274,
#  'change': 275,
#  'voters': 276,
#  'plan': 277,
#  'trade': 278,
#  'month': 279,
#  'information': 280,
#  'leaders': 281,
#  'south': 282,
#  'family': 283,
#  'speech': 284,
#  'decision': 285,
#  'business': 286,
#  'international': 287,
#  'groups': 288,
#  'reported': 289,
#  'fact': 290,
#  'days': 291,
#  'interview': 292,
#  'long': 293,
#  'already': 294,
#  'director': 295,
#  'story': 296,
#  'several': 297,
#  'again': 298,
#  'far': 299,
#  'too': 300,
#  'conservative': 301,
#  'fox': 302,
#  'chief': 303,
#  'likely': 304,
#  'must': 305,
#  'health': 306,
#  'call': 307,
#  'border': 308,
#  'john': 309,
#  'something': 310,
#  'place': 311,
#  'months': 312,
#  'immigration': 313,
#  'clear': 314,
#  'supporters': 315,
#  'agency': 316,
#  'social': 317,
#  'home': 318,
#  'islamic': 319,
#  'among': 320,
#  'watch': 321,
#  'sanders': 322,
#  'move': 323,
#  'press': 324,
#  'post': 325,
#  'believe': 326,
#  'however': 327,
#  'barack': 328,
#  'got': 329,
#  'program': 330,
#  'issue': 331,
#  'billion': 332,
#  'won': 333,
#  'act': 334,
#  'might': 335,
#  'children': 336,
#  'major': 337,
#  'came': 338,
#  'muslim': 339,
#  'recent': 340,
#  'least': 341,
#  'sunday': 342,
#  'killed': 343,
#  'seen': 344,
#  'found': 345,
#  'things': 346,
#  'number': 347,
#  'great': 348,
#  'control': 349,
#  'trying': 350,
#  've': 351,
#  'democrat': 352,
#  'matter': 353,
#  'today': 354,
#  'though': 355,
#  'didn': 356,
#  'reporters': 357,
#  'later': 358,
#  'win': 359,
#  'defense': 360,
#  'm': 361,
#  'attacks': 362,
#  'yet': 363,
#  'economic': 364,
#  'eu': 365,
#  'march': 366,
#  'making': 367,
#  'spokesman': 368,
#  'working': 369,
#  'went': 370,
#  'executive': 371,
#  'become': 372,
#  'actually': 373,
#  'school': 374,
#  'look': 375,
#  'cnn': 376,
#  'keep': 377,
#  'stop': 378,
#  'big': 379,
#  'free': 380,
#  'give': 381,
#  'little': 382,
#  'nation': 383,
#  'system': 384,
#  'legal': 385,
#  'un': 386,
#  'set': 387,
#  'past': 388,
#  'violence': 389,
#  'cruz': 390,
#  'until': 391,
#  'real': 392,
#  'forces': 393,
#  'himself': 394,
#  'senior': 395,
#  'earlier': 396,
#  'away': 397,
#  'doesn': 398,
#  'let': 399,
#  'four': 400,
#  'thing': 401,
#  'point': 402,
#  'added': 403,
#  'governor': 404,
#  'talks': 405,
#  'member': 406,
#  'doing': 407,
#  'lawmakers': 408,
#  'nothing': 409,
#  'january': 410,
#  'comment': 411,
#  'illegal': 412,
#  'sanctions': 413,
#  'woman': 414,
#  'ever': 415,
#  'wall': 416,
#  'few': 417,
#  'opposition': 418,
#  'head': 419,
#  'european': 420,
#  'local': 421,
#  'taking': 422,
#  'nations': 423,
#  'force': 424,
#  'known': 425,
#  'issues': 426,
#  'human': 427,
#  'following': 428,
#  'nominee': 429,
#  'july': 430,
#  'prime': 431,
#  'companies': 432,
#  'possible': 433,
#  'held': 434,
#  'gun': 435,
#  'gop': 436,
#  'attorney': 437,
#  'care': 438,
#  'supreme': 439,
#  'wants': 440,
#  'action': 441,
#  'across': 442,
#  '2015': 443,
#  'judge': 444,
#  'team': 445,
#  'released': 446,
#  'pay': 447,
#  'person': 448,
#  'expected': 449,
#  'union': 450,
#  'men': 451,
#  'continue': 452,
#  'job': 453,
#  'community': 454,
#  'better': 455,
#  'company': 456,
#  'enough': 457,
#  'others': 458,
#  'given': 459,
#  'high': 460,
#  'night': 461,
#  'once': 462,
#  'legislation': 463,
#  'evidence': 464,
#  'ban': 465,
#  'financial': 466,
#  '10': 467,
#  'response': 468,
#  'history': 469,
#  'reports': 470,
#  'taken': 471,
#  'source': 472,
#  'budget': 473,
#  'process': 474,
#  'question': 475,
#  'face': 476,
#  'open': 477,
#  'images': 478,
#  'close': 479,
#  'fight': 480,
#  'done': 481,
#  'wrote': 482,
#  'debate': 483,
#  '20': 484,
#  'special': 485,
#  'plans': 486,
#  'important': 487,
#  'life': 488,
#  'syrian': 489,
#  'june': 490,
#  'course': 491,
#  'having': 492,
#  'university': 493,
#  'refugees': 494,
#  'anyone': 495,
#  'lot': 496,
#  'race': 497,
#  'run': 498,
#  'majority': 499,
#  'private': 500,
#  'email': 501,
#  'iraq': 502,
#  'using': 503,
#  'second': 504,
#  'death': 505,
#  'air': 506,
#  'crisis': 507,
#  'putin': 508,
#  'staff': 509,
#  'despite': 510,
#  'conference': 511,
#  'saturday': 512,
#  'further': 513,
#  'comments': 514,
#  'november': 515,
#  'anything': 516,
#  'efforts': 517,
#  'behind': 518,
#  'accused': 519,
#  'along': 520,
#  'lives': 521,
#  'ago': 522,
#  'able': 523,
#  'ryan': 524,
#  'mexico': 525,
#  'best': 526,
#  'saudi': 527,
#  '1': 528,
#  'agreement': 529,
#  'mr': 530,
#  'role': 531,
#  'early': 532,
#  'find': 533,
#  'full': 534,
#  'future': 535,
#  'am': 536,
#  'less': 537,
#  'region': 538,
#  'lead': 539,
#  'instead': 540,
#  'letter': 541,
#  'comes': 542,
#  'council': 543,
#  'weeks': 544,
#  'five': 545,
#  'jobs': 546,
#  'current': 547,
#  'within': 548,
#  'due': 549,
#  'someone': 550,
#  'civil': 551,
#  'visit': 552,
#  'facebook': 553,
#  'calling': 554,
#  'sure': 555,
#  'sources': 556,
#  'comey': 557,
#  'service': 558,
#  'hard': 559,
#  'coalition': 560,
#  'students': 561,
#  'getting': 562,
#  'texas': 563,
#  'live': 564,
#  'name': 565,
#  'britain': 566,
#  'rules': 567,
#  'center': 568,
#  'young': 569,
#  'congressional': 570,
#  'votes': 571,
#  'israel': 572,
#  'economy': 573,
#  'coming': 574,
#  'effort': 575,
#  'll': 576,
#  'elections': 577,
#  'calls': 578,
#  'muslims': 579,
#  'candidates': 580,
#  'emails': 581,
#  'announced': 582,
#  'weapons': 583,
#  'army': 584,
#  'global': 585,
#  'paul': 586,
#  'thousands': 587,
#  'ties': 588,
#  'line': 589,
#  'healthcare': 590,
#  'citizens': 591,
#  'event': 592,
#  'running': 593,
#  'chairman': 594,
#  'nearly': 595,
#  'sent': 596,
#  'climate': 597,
#  'talk': 598,
#  '8': 599,
#  'obamacare': 600,
#  'racist': 601,
#  'fake': 602,
#  'claims': 603,
#  'street': 604,
#  '2014': 605,
#  'allow': 606,
#  'rule': 607,
#  'daily': 608,
#  'capital': 609,
#  'poll': 610,
#  'position': 611,
#  'each': 612,
#  'workers': 613,
#  'december': 614,
#  'whose': 615,
#  'october': 616,
#  'middle': 617,
#  'ruling': 618,
#  'led': 619,
#  'hold': 620,
#  'wanted': 621,
#  'tell': 622,
#  'needs': 623,
#  'message': 624,
#  'latest': 625,
#  'outside': 626,
#  'april': 627,
#  'everyone': 628,
#  'late': 629,
#  'threat': 630,
#  'authorities': 631,
#  'gave': 632,
#  'east': 633,
#  'liberal': 634,
#  'began': 635,
#  'turkey': 636,
#  'problem': 637,
#  'florida': 638,
#  'makes': 639,
#  'bad': 640,
#  'showed': 641,
#  'reform': 642,
#  'politics': 643,
#  '15': 644,
#  'officers': 645,
#  'leave': 646,
#  'rally': 647,
#  'september': 648,
#  'immigrants': 649,
#  'bush': 650,
#  'd': 651,
#  'criminal': 652,
#  'questions': 653,
#  'voting': 654,
#  'failed': 655,
#  'means': 656,
#  'organization': 657,
#  'august': 658,
#  'isn': 659,
#  'start': 660,
#  'representatives': 661,
#  'relations': 662,
#  'meet': 663,
#  'reason': 664,
#  'immediately': 665,
#  'peace': 666,
#  'lost': 667,
#  'list': 668,
#  'words': 669,
#  'parliament': 670,
#  'together': 671,
#  'cut': 672,
#  'release': 673,
#  'access': 674,
#  'speaking': 675,
#  'policies': 676,
#  'services': 677,
#  'hope': 678,
#  'stand': 679,
#  'germany': 680,
#  'funding': 681,
#  'february': 682,
#  'different': 683,
#  'rather': 684,
#  'central': 685,
#  'conservatives': 686,
#  'agencies': 687,
#  'george': 688,
#  '2': 689,
#  'ahead': 690,
#  'spending': 691,
#  'based': 692,
#  'tried': 693,
#  'allies': 694,
#  'strong': 695,
#  'read': 696,
#  'ministry': 697,
#  'laws': 698,
#  'sexual': 699,
#  'planned': 700,
#  'almost': 701,
#  'try': 702,
#  '2017': 703,
#  'millions': 704,
#  'cannot': 705,
#  'thought': 706,
#  'received': 707,
#  'oil': 708,
#  'six': 709,
#  'recently': 710,
#  'allowed': 711,
#  'morning': 712,
#  'host': 713,
#  '30': 714,
#  'elected': 715,
#  'protect': 716,
#  'idea': 717,
#  'shows': 718,
#  'enforcement': 719,
#  'bring': 720,
#  'shooting': 721,
#  'charges': 722,
#  'decided': 723,
#  'missile': 724,
#  'old': 725,
#  'fire': 726,
#  'key': 727,
#  'room': 728,
#  'europe': 729,
#  'concerns': 730,
#  'parties': 731,
#  'provide': 732,
#  'chinese': 733,
#  'entire': 734,
#  'often': 735,
#  'talking': 736,
#  'met': 737,
#  'always': 738,
#  'near': 739,
#  'involved': 740,
#  'situation': 741,
#  'hate': 742,
#  'obamas': 743,
#  'energy': 744,
#  'happened': 745,
#  'officer': 746,
#  'district': 747,
#  'kind': 748,
#  '3': 749,
#  'shot': 750,
#  'bank': 751,
#  'allegations': 752,
#  'denied': 753,
#  'tweet': 754,
#  'everything': 755,
#  'presidency': 756,
#  'california': 757,
#  'small': 758,
#  'movement': 759,
#  'james': 760,
#  'looking': 761,
#  'terrorist': 762,
#  'vice': 763,
#  'century': 764,
#  'travel': 765,
#  'needed': 766,
#  'arrested': 767,
#  'myanmar': 768,
#  'freedom': 769,
#  'especially': 770,
#  'agreed': 771,
#  'side': 772,
#  'voted': 773,
#  'include': 774,
#  'water': 775,
#  'return': 776,
#  'bernie': 777,
#  'nomination': 778,
#  'hours': 779,
#  'large': 780,
#  'protesters': 781,
#  'documents': 782,
#  'area': 783,
#  'potential': 784,
#  'industry': 785,
#  'korean': 786,
#  'crime': 787,
#  'data': 788,
#  'request': 789,
#  'british': 790,
#  'west': 791,
#  '12': 792,
#  'themselves': 793,
#  'market': 794,
#  'seems': 795,
#  'although': 796,
#  'fired': 797,
#  'representative': 798,
#  'personal': 799,
#  'fighting': 800,
#  'county': 801,
#  'hearing': 802,
#  'claim': 803,
#  'adviser': 804,
#  'polls': 805,
#  'wife': 806,
#  'hit': 807,
#  'western': 808,
#  'cases': 809,
#  '2012': 810,
#  'adding': 811,
#  'actions': 812,
#  'foundation': 813,
#  'either': 814,
#  'insurance': 815,
#  'confirmed': 816,
#  'worked': 817,
#  'true': 818,
#  'interest': 819,
#  'serious': 820,
#  'decades': 821,
#  'pressure': 822,
#  'wrong': 823,
#  'forward': 824,
#  'alleged': 825,
#  'building': 826,
#  'realdonaldtrump': 827,
#  'step': 828,
#  '11': 829,
#  'front': 830,
#  'term': 831,
#  'commission': 832,
#  '5': 833,
#  'address': 834,
#  'leading': 835,
#  'details': 836,
#  'j': 837,
#  'spoke': 838,
#  'claimed': 839,
#  'tillerson': 840,
#  'paid': 841,
#  'biggest': 842,
#  'probably': 843,
#  'nov': 844,
#  'lawyer': 845,
#  'love': 846,
#  'passed': 847,
#  'college': 848,
#  'continued': 849,
#  'clearly': 850,
#  '4': 851,
#  'review': 852,
#  'feel': 853,
#  'board': 854,
#  'truth': 855,
#  'main': 856,
#  'families': 857,
#  'appeared': 858,
#  'final': 859,
#  'primary': 860,
#  'victory': 861,
#  'ted': 862,
#  'soon': 863,
#  'moscow': 864,
#  'leadership': 865,
#  'michael': 866,
#  'son': 867,
#  'mean': 868,
#  'protest': 869,
#  'father': 870,
#  'mike': 871,
#  'taxes': 872,
#  'turn': 873,
#  'terrorism': 874,
#  'network': 875,
#  'dont': 876,
#  'aid': 877,
#  'record': 878,
#  'brought': 879,
#  'dollars': 880,
#  'sessions': 881,
#  'declined': 882,
#  'cia': 883,
#  'result': 884,
#  'deputy': 885,
#  'wasn': 886,
#  'simply': 887,
#  'goes': 888,
#  'toward': 889,
#  'points': 890,
#  'remarks': 891,
#  'turned': 892,
#  'issued': 893,
#  'sign': 894,
#  'became': 895,
#  'started': 896,
#  'independence': 897,
#  'spent': 898,
#  'arabia': 899,
#  'protests': 900,
#  'pence': 901,
#  'david': 902,
#  'posted': 903,
#  'flynn': 904,
#  'included': 905,
#  'mayor': 906,
#  'agenda': 907,
#  'signed': 908,
#  'secret': 909,
#  'view': 910,
#  'isis': 911,
#  '25': 912,
#  'religious': 913,
#  'influence': 914,
#  'attempt': 915,
#  'mccain': 916,
#  'article': 917,
#  'push': 918,
#  'town': 919,
#  'popular': 920,
#  'mark': 921,
#  'previously': 922,
#  'rubio': 923,
#  'forced': 924,
#  'german': 925,
#  'raised': 926,
#  'merkel': 927,
#  'below': 928,
#  'pass': 929,
#  'fund': 930,
#  'relationship': 931,
#  'guy': 932,
#  'pretty': 933,
#  'food': 934,
#  'child': 935,
#  'level': 936,
#  '2013': 937,
#  'giving': 938,
#  'clintons': 939,
#  'seeking': 940,
#  'half': 941,
#  'al': 942,
#  'saw': 943,
#  'militants': 944,
#  'account': 945,
#  'website': 946,
#  'short': 947,
#  'convention': 948,
#  'gets': 949,
#  'speak': 950,
#  'cost': 951,
#  'conflict': 952,
#  'helped': 953,
#  'debt': 954,
#  'speaker': 955,
#  'friends': 956,
#  'proposed': 957,
#  'total': 958,
#  'increase': 959,
#  'firm': 960,
#  'hundreds': 961,
#  'voter': 962,
#  'ask': 963,
#  'ambassador': 964,
#  'reality': 965,
#  'armed': 966,
#  'wire': 967,
#  'described': 968,
#  'longer': 969,
#  'repeatedly': 970,
#  'phone': 971,
#  'remain': 972,
#  'created': 973,
#  'largest': 974,
#  'regional': 975,
#  'independent': 976,
#  'fear': 977,
#  'areas': 978,
#  'heard': 979,
#  'violent': 980,
#  'constitution': 981,
#  'discuss': 982,
#  'tv': 983,
#  'hand': 984,
#  'troops': 985,
#  'changes': 986,
#  'respond': 987,
#  'education': 988,
#  'currently': 989,
#  'criticized': 990,
#  'similar': 991,
#  'funds': 992,
#  'flag': 993,
#  'victims': 994,
#  'brexit': 995,
#  'build': 996,
#  'whole': 997,
#  'carolina': 998,
#  'crowd': 999,
#  'senators': 1000,
#  ...}

# %%
#histogram to show total numbers of words in the news
plt.hist([len(i) for i in x],bins = 700)
plt.show()

# %%
#truncate news with more than 1000 words
nos = np.array([len(i) for i in x])
nos[nos>1000]
len(nos[nos>1000])
# Out:
# 1584

# %%
maxlen = 1000
x = pad_sequences(x,maxlen = maxlen)

# %%
len(x[101])
# Out:
# 1000

# %% [markdown]
# feeding the vectors as initial weight to the training model

# %%
vocab_size = len(tokenizer.word_index)+1
vocab = tokenizer.word_index

# %%
#getting the weight matrix
def get_weight_matrix(model):
  weight_matrix = np.zeros((vocab_size,DIM))
  for word, i in vocab.items():
    weight_matrix[i] = model.wv[word]
  
  return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
#shape of embediding vector
embedding_vectors.shape
# Out:
# (231912, 100)

# %%
#model architecture
model = Sequential()
model.add(Embedding(vocab_size,output_dim = DIM,weights = [embedding_vectors],input_length = maxlen,trainable = False))
model.add(LSTM(units = 128))
model.add(Dense(1,activation = "sigmoid"))
model.compile(optimizer = "adam", loss = "binary_crossentropy",metrics = ["acc"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1000, 100)         23191200
#
#  lstm (LSTM)                 (None, 128)               117248
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 23,308,577
# Trainable params: 117,377
# Non-trainable params: 23,191,200
# _________________________________________________________________

# %%
#splitting the dataset into training and testing data
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
model.fit(x_train, y_train,validation_split = 0.3,epochs = 6)
# Out:
# Epoch 1/6
# 688/688 [==============================] - 863s 1s/step - loss: 0.0657 - acc: 0.9778 - val_loss: 0.0624 - val_acc: 0.9785
# Epoch 2/6
# 688/688 [==============================] - 863s 1s/step - loss: 0.0394 - acc: 0.9873 - val_loss: 0.0294 - val_acc: 0.9905
# Epoch 3/6
# 688/688 [==============================] - 860s 1s/step - loss: 0.0228 - acc: 0.9929 - val_loss: 0.0242 - val_acc: 0.9935
# Epoch 4/6
# 688/688 [==============================] - 860s 1s/step - loss: 0.0183 - acc: 0.9943 - val_loss: 0.0162 - val_acc: 0.9954
# Epoch 5/6
# 688/688 [==============================] - 856s 1s/step - loss: 0.0108 - acc: 0.9970 - val_loss: 0.0160 - val_acc: 0.9952
# Epoch 6/6
# 688/688 [==============================] - 864s 1s/step - loss: 0.0233 - acc: 0.9927 - val_loss: 0.0715 - val_acc: 0.9755

# %%
#validating training data
y_pred_Train= (model.predict(x_train) >= 0.5).astype(int)

# %%
#validatimg test data
y_pred_Test = (model.predict(x_test) >= 0.5).astype(int)

# %%
#classification report of training data
print(classification_report(y_train,y_pred_Train))

# %%
#classification report of testing data
print(classification_report(y_test,y_pred_Test))

# %%
#converting the random news into sequences
rand= ["this is a news"]
rand = tokenizer.texts_to_sequences(rand)
rand = pad_sequences(rand,maxlen = maxlen)

# %%
#model being used to predict the result
result = (model.predict(rand) >= 0.5).astype(int)
result
# Out:
# array([[0]])

# %%
if result[[0]] == 0:
  print("false")
else:
  print("True")
# Out:
# false

# %%
rand = ["India today reported 3,714 new coronavirus infections, taking the tally of COVID-19 cases to 4,31,85,049, according to the Union Health Ministry data updated"]
rand = tokenizer.texts_to_sequences(rand)
rand = pad_sequences(rand,maxlen = maxlen)
result = (model.predict(rand) >= 0.5).astype(int)
result
if result[[0]] == 0:
  print("false")
else:
  print("True")

# %%
# Constructing the confusion matrix.
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train, y_pred_Train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-b3741d6854de> in <module>()
#       1 # Constructing the confusion matrix.
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 confusion_matrix(y_train, y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [31428, 13470]
